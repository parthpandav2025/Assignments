# %% [markdown]
# **Theory Questions** : -

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?

# %% [markdown]
# > Compiled languages me code pehle machine code me convert hota hai (fast execution), jabki interpreted languages me code line-by-line execute hota hai (flexible but slow). Example: C (compiled), Python (interpreted)

# %% [markdown]
# 2. What is exception handling in Python?

# %% [markdown]
# > Exception handling ek mechanism hai jisme try-except ka use karke errors ko handle kiya jata hai taaki program crash na ho.

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?
#
# >Answer:
# finally block hamesha execute hota hai, chahe exception aaye ya na aaye. Mostly cleanup (file close, resources free) ke liye use hota hai.

# %% [markdown]
# 4. What is logging in Python?
#
# >Answer:
# Logging ka matlab hai program ke events aur errors ko record karna for debugging aur monitoring.

# %% [markdown]
# 5. What is the significance of the del method in Python?
#
# >Answer:
# __del__ ek destructor method hai jo object destroy hone par automatically call hota hai.

# %% [markdown]
# 6. What is the difference between import and from ... import in Python?
#
# >Answer:
# import module se pura module import hota hai, jabki from module import name se specific function ya variable import hota hai.

# %% [markdown]
# 7. How can you handle multiple exceptions in Python?
#
# >Answer:
# Ek hi except me multiple exceptions handle kar sakte hain:

# %%
try:
    pass
except (TypeError, ValueError):
    pass

# %% [markdown]
# 8. What is the purpose of the with statement when handling files in Python?
#
# >Answer:
# with statement file ko automatically close kar deta hai, isse resource management safe ho jata hai.

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing?
#
# >Answer:
# Multithreading me threads same memory share karte hain, jabki multiprocessing me alag processes hoti hain aur better CPU usage milta hai.

# %% [markdown]
# 10. What are the advantages of using logging in a program?
#
# >Answer:
# Logging se debugging easy hoti hai, errors track hote hain aur program monitor karna easy hota hai.
#
# 11. What is memory management in Python?
#
# >Answer:
# Python me memory management automatic hota hai using reference counting aur garbage collection.
#
# 12. What are the basic steps involved in exception handling in Python?
#
# >Answer:
# Basic steps: try → except → else → finally
#
# 13. Why is memory management important in Python?
#
# >Answer:
# Efficient memory management se performance improve hoti hai aur memory leaks avoid hote hain.
#
# 14. What is the role of try and except in exception handling?
#
# >Answer:
# try me risky code likha jata hai aur except me error handle kiya jata hai.
#
# 15. How does Python’s garbage collection system work?
#
# >Answer:
# Python unused objects ko automatically delete karta hai using garbage collection.
#
# 16. What is the purpose of the else block in exception handling?
#
# >Answer:
# else tab execute hota hai jab try block me koi error nahi aata.
#
# 17. What are the common logging levels in Python?
#
# >Answer:
# DEBUG, INFO, WARNING, ERROR, CRITICAL
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
# >Answer:
# os.fork() sirf Unix systems me kaam karta hai, jabki multiprocessing cross-platform hai.
#
# 19. What is the importance of closing a file in Python?
#
# >Answer:
# File close karne se memory free hoti hai aur data corruption avoid hota hai.
#
# 20. What is the difference between file.read() and file.readline() in Python?
#
# >Answer:
# read() pura file read karta hai, jabki readline() ek line read karta hai.
#
# 21. What is the logging module in Python used for?
#
# >Answer:
# logging module ka use logs create aur manage karne ke liye hota hai.
#
# 22. What is the os module in Python used for in file handling?
#
# >Answer:
# os module ka use file create, delete aur directories manage karne ke liye hota hai.

# %% [markdown]
# 23. What are the challenges associated with memory management in Python?
#
# >Answer:
# Memory leaks, high memory usage aur performance issues common challenges hain.
#
# 24. How do you raise an exception manually in Python?
#
# >Answer:
# raise keyword ka use karke:

# %% [raw]
# raise ValueError("Error message")

# %% [markdown]
# **Practicle Questions**

# %%
#1  How can you open a file for writing in Python and write a string to it?
with open("file.txt", "w") as f:
    f.write("Hello World")

# %%
#2  Write a Python program to read the contents of a file and print each line.
with open("file.txt", "r") as f:
    for line in f:
        print(line)
# Out:
# Hello World

# %%
#3 How would you handle a case where the file doesn't exist while trying to open it for reading?

try:
    with open("file.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("File not found")
# Out:
# Hello World

# %%
#4 Write a Python script that reads from one file and writes its content to another file.

with open("file.txt", "r") as f1 , open("file.txt", "w") as f2:
    f2.write(f1.read())

# %%
#5 How would you catch and handle division by zero error in Python?

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
#6 Write a Python program that logs an error message to a log file when a division by zero exception occurs.

import logging
logging.basicConfig(filename="log.txt", level=logging.ERROR)
try:
    10 / 0
except ZeroDivisionError:
    logging.error("Division by zero occurred")

# %%
with open("log.txt","r") as f:
    for i in f:
        print(i)
# Out:
# ERROR:root:Division by zero occurred
#
# ERROR:root:Error message

# %%
#7 How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

import logging
logging.basicConfig(level=logging.DEBUG)
logging.info("Info message")
logging.warning("Warning message")
logging.error("Error message")

# %%
#8 Write a program to handle a file opening error using exception handling.

try:
    f = open("file.txt", "r")
except Exception:
    print("Error opening file")

# %%
#9 How can you read a file line by line and store its content in a list in Python?

with open("file.txt", "r") as f:
    for i in f:
        lines = i.readlines()
        print(lines)

# %%
#10 How can you append data to an existing file in Python?

with open("file.txt", "a") as f:
    f.write("New Data\n")

# %%
#11 Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

d = {"a": 1}
try:
    print(d["b"])
except KeyError:
    print("Key not found")
# Out:
# Key not found

# %%
#12 Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

try:
    x = int("abc")
except ValueError:
    print("Value Error")
except TypeError:
    print("Type Error")
# Out:
# Value Error

# %%
#13 How would you check if a file exists before attempting to read it in Python?

import os
if os.path.exists("file.txt"):
    print("File exists")
# Out:
# File exists

# %%
#14 Write a program that uses the logging module to log both informational and error messages.

import logging
logging.basicConfig(filename="log.txt", level=logging.DEBUG)
logging.info("Info message")
logging.error("Error message")

# %%
#15 Write a Python program that prints the content of a file and handles the case when the file is empty.

with open("file.txt", "r") as f:
    data = f.read()
    if data:
        print(data)
    else:
        print("File is empty")
# Out:
# New Data

# %%
#16 Demonstrate how to use memory profiling to check the memory usage of a small program.

from memory_profiler import profile

@profile
def test():
    a = [i for i in range(10000)]
test()
# Out:
# ERROR: Could not find file C:\Users\Pandav\AppData\Local\Temp\ipykernel_21348\358774998.py

# %%
#17 Write a Python program to create and write a list of numbers to a file, one number per line.

with open("nums.txt", "w") as f:
    for i in range(10):
        f.write(str(i) + "\n")

# %%
#18 How would you implement a basic logging setup that logs to a file with rotation after 1MB?

import logging
from logging.handlers import RotatingFileHandler
handler = RotatingFileHandler("log.txt", maxBytes=1000000, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.DEBUG)

# %%
#19 Write a program that handles both IndexError and KeyError using a try-except block.

try:
    l = [1,2]
    print(l[5])
    d = {"a":1}
    print(d["b"])
except IndexError:
    print("Index Error")
except KeyError:
    print("Key Error")
# Out:
# Index Error

# %%
#20 How would you open a file and read its contents using a context manager in Python?

with open("file.txt", "r") as f:
    data = f.read()
    pr

# %%
#21 Write a Python program that reads a file and prints the number of occurrences of a specific word.

with open("file.txt", "r") as f:
data = f.read()
print(data.count("word"))

# %%
#22 How can you check if a file is empty before attempting to read its contents?

import os
if os.stat("file.txt").st_size == 0:
print("File is empty")

# %%
#23 Write a Python program that writes to a log file when an error occurs during file handling.

import logging
logging.basicConfig(filename="log.txt", level=logging.ERROR)
try:
open("file.txt")
except Exception as e:
logging.error(str(e))
