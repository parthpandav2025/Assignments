# %% [markdown]
# **Theory Question**

# %% [markdown]
# 1 What is NumPy, and why is it widely used in Python?
#
# >NumPy is a library for numerical computing that provides fast array operations and efficient mathematical functions.
#
# 2 How does broadcasting work in NumPy?
#
# >Broadcasting allows NumPy to perform operations on arrays of different shapes without explicit loops.
#
# 3 What is a Pandas DataFrame?
#
# >A DataFrame is a 2D labeled data structure in Pandas similar to a table with rows and columns.
#
# 4 Explain the use of the groupby() method in Pandas.
#
# >groupby() is used to split data into groups and perform aggregate operations like sum, mean, count.
#
# 5 Why is Seaborn preferred for statistical visualizations?
#
# >Seaborn provides built-in themes and better statistical plots with less code compared to Matplotlib.
#
# 6 What are the differences between NumPy arrays and Python lists?
#
# >NumPy arrays are faster, support vectorized operations, and use less memory compared to Python lists.
#
# 7 What is a heatmap, and when should it be used?
#
# >A heatmap shows data values using colors and is used to visualize correlations or patterns.
#
# 8 What does the term "vectorized operation" mean in NumPy?
#
# >It means performing operations on entire arrays without using loops, making it faster.
#
# 9 How does Matplotlib differ from Plotly?
#
# >Matplotlib is static, while Plotly provides interactive visualizations.
#
# 10 What is the significance of hierarchical indexing in Pandas?
#
# >It allows multiple levels of indexing, making it easier to work with complex data.
#
# 11 What is the role of Seaborn’s pairplot() function?
#
# >pairplot() shows pairwise relationships between variables using scatter plots.
#
# 12 What is the purpose of the describe() function in Pandas?
#
# >It provides summary statistics like mean, std, min, max, etc.
#
# 13 Why is handling missing data important in Pandas?
#
# >Missing data can affect analysis accuracy, so it must be handled properly.
#
# 14 What are the benefits of using Plotly for data visualization?
#
# >Plotly provides interactive charts, zooming, and better user experience.
#
# 15 How does NumPy handle multidimensional arrays?
#
# >NumPy uses ndarray objects to efficiently store and process multi-dimensional data.
#
# 16 What is the role of Bokeh in data visualization?
#
# >Bokeh is used for interactive web-based visualizations.
#
# 17 Explain the difference between apply() and map() in Pandas.
#
# >apply() works on rows/columns, while map() works on a single column.
#
# 18 What are some advanced features of NumPy?
#
# >Broadcasting, vectorization, linear algebra, random functions.
#
# 19 How does Pandas simplify time series analysis?
#
# >It provides date-time indexing, resampling, and rolling window functions.
#
# 20 What is the role of a pivot table in Pandas?
#
# >It summarizes data by aggregating values based on categories.
#
# 21 Why is NumPy’s array slicing faster than Python’s list slicing?
#
# >Because NumPy uses optimized C-based operations and memory efficiency.
#
# 22 What are some common use cases for Seaborn?
#
# >Correlation plots, distribution plots, regression plots, heatmaps.

# %% [markdown]
# **Practical Questions**

# %%
import pandas as pd
import numpy as np

# %%
#1  How do you create a 2D NumPy array and calculate the sum of each row?
arr = np.array([[1,2,3,4,5]])
arr.sum()
# Out:
# 15

# %%
#2 Write a Pandas script to find the mean of a specific column in a DataFrame.

data = pd.DataFrame([1,2,3,4,5],columns=["Col"])
data.mean()
# Out:
# Col    3.0
# dtype: float64

# %%
#3 Create a scatter plot using Matplotlib.
import matplotlib.pyplot as plt
data = pd.DataFrame({"A" : [5,10,15,20,25] , "B" : [8,16,24,32,40]})
plt.scatter(data["A"],data["B"])
plt.show()

# %%
#4 How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap
import seaborn as sns

sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
#5 Generate a bar plot using Plotly.

import plotly.express as px

px.bar(data)

# %%
#6 Create a DataFrame and add a new column based on an existing column.

data = pd.DataFrame()
data["new"] = [1,2,3]
data
# Out:
#    new
# 0    1
# 1    2
# 2    3

# %%
#7 Write a program to perform element-wise multiplication of two NumPy arrays.
arr_1 = np.array([[1,2,3,4,5]])
arr_2 = np.array([[6,7,8,9,10]])
arr_1 * arr_2
# Out:
# array([[ 6, 14, 24, 36, 50]])

# %%
#8 Create a line plot with multiple lines using Matplotlib.

plt.plot([1,2,3],[4,5,6],color="r",label="red_line")
plt.plot([1,2,3],[6,5,4],color="g",label="green_line")
plt.legend()
plt.show()

# %%
#9 Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold.

data[data["new"] >= 2]
# Out:
#    new
# 1    2
# 2    3

# %%
#10 Create a histogram using Seaborn to visualize a distribution.
sns.histplot([1,1,1,2,3,4,4,5,5,6,7],kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#11 Perform matrix multiplication using NumPy.
np.dot(data["new"] , data["old"])
# Out:
# 180

# %%
#12 Use Pandas to load a CSV file and display its first 5 rows.
data = pd.read_csv("data.csv")
data.head(5)
